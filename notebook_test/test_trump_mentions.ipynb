# %% [markdown]
# Practice session 5

# %%
myText= "One by one, the free lands of Middle-Earth fell to the power of the Ring, but there were some who resisted. A last alliance of men and elves marched against the armies of Mordor, and on the very slopes of Mount Doom, they fought for the freedom of Middle-Earth. Victory was near, but the power of the ring could not be undone. It was in this moment, when all hope had faded, that Isildur, son of the king, took up his father’s sword."

# %%
myText=myText.split()
for word in myText:
    if word.startswith('t') or word.startswith('T')or word.startswith('d') or word.startswith('D'):
        print(word)
    else:
        pass
# Out:
# the
# to
# the
# the
# there
# the
# the
# Doom,
# they
# the
# the
# the
# this
# that
# the
# took

# %% [markdown]
# Trump Tweets

# %%
f = open("/Users/owner/Desktop/MELLing/MELLing Sem 3/Python_for_Linguists/TrumpTweets/2020.txt", "r")
TrumpTweets = f.read()
#TrumpTweets.close()

# %%
mentioned_list = []
for word in TrumpTweets.split():
     if word.startswith("@"):
        mentioned_list.append(word)

print(mentioned_list)
# Out:
# ['@DevinNunes:', '@heatherjones333:', '@heatherjones333:', '@heatherjones333:', '@heatherjones333:', '@heatherjones333:', '@dcexaminer', '@LindseyGrahamSC:', '@realDonaldTrump', '@dcexaminer:', '@LindseyGrahamSC', '@realDonaldTrump', '@LindseyGrahamSC:', '@realDonaldTrump', '@LindseyGrahamSC:', '@LindseyGrahamSC:', '@SenJohnKennedy:', "@SenJoniErnst's", '@ThisWeekABC:', '@SenJohnKennedy:', '@DanScavino:', '@Scavino45:', '@Scavino45:', '@ATT', '@CNN', '@CLewandowski_:', '@realDonaldTrump.', '@GOPChairwoman:', '@realDonaldTrump.This', '@VP:', '@realDonaldTrump’s', '@TeamTrump:', '@realDonaldTrump', '@GOPChairwoman:', '@DanScavino:', '@DanScavino:', '@DanScavino:', '@FoxNews', '@cvpayne', '@BuckSexton:', '@JesseKellyDC:', '@USEmbBaghdad:', '@TravelGov:', '@jimsciutto:', '@samdagher:', '@DineshDSouza:', '@SecPompeo:', '@KimStrassel:', '@W...', '@WhiteHouse:', '@abigailmarone:', '@RepMarkMeadows:', '@mrglenn:', '@JackPosobiec:', '@hughhewitt:', '@SecPompeo', '@foxandfriends.', '@LeeSmithDC:', '@Liz_Wheeler:', '@GrahamLedger:', '@WhiteHouse:', '@realDonaldTrump:', '@realDonaldTrump:', '@LindseyGrahamSC', '@MariaBartiromo', '@TuckerCarlson:', '@SenateGOP:', '@realdonaldtrump', '@Jim_Jordan:', '@realDonaldTrump:', '@LouDobbs:', '@TomFitton', '@JudicialWatch', '@TomFitton:', '@TomFitton:', '@GOPChairwoman:', '@TeamTrump:', '@realDonaldTrump', '@BradThor:', '@marcthiessen:', '@hughhewitt:', '@marcthiessen:', '@ByronYork:', '@marcorubio:', '@marcorubio:', '@LindseyGrahamSC:', '@LindseyGrahamSC:', '@SpeakerPelosi’s', '@LindseyGrahamSC:', '@LindseyGrahamSC:', '@LindseyGrahamSC:', '@SpeakerPelosi', '@LindseyGrahamSC:', "@tedcruz's", "@realDonaldTrump's", '@LindseyGrahamSC:', '@tedcruz', '@realDonaldTrump', '@LindseyGrahamSC:', '@realDonaldTrump’s', '@VP', '@SecPompeo,', '@EsperDoD,', '@LindseyGrahamSC:', '@LindseyGrahamSC:', '@realDonaldTrump', '@LindseyGrahamSC:', '@JudgeJeanine:', '@RepMarkMeadows:', '@GOPLeader', '@foxandfriends.', '@kbsalsaud', '@WhiteHouse:', '@realDonaldTrump', '@JennyGuice:', '@realDonaldTrump', '@TeamTrump:', '@mike_pence:', '@realDonaldTrump', '@Mike_Pence:', '@realDonaldTrump', '@GOPChairwoman:', '@realDonaldTrump', '@TeamTrump:', '@IvankaTrump', '@realDonaldTrump!', '@piersmorgan:', '@realDonaldTrump', '@Scavino45:', '@realDonaldTru...', '@marcorubio:', '@marcorubio:', '@senatemajldr:', '@EliseStefanik:', '@MatthewJshow:', '@realDonaldTrump', '@StewardshipAmer:', '@realDonaldTrump', '@realDonaldTrump,', '@foxandfriends', '@LindseyGrahamSC:', '@LindseyGrahamSC:', '@sendavidperdue:', '@realDonaldTrump', '@sendavidperdue:', '@realDonaldTrump', '@SenTomCotton:', '@SenTomCotton:', '@SenTomCotton:', '@SenDanSullivan:', '@GovernorLittle:', '@MikeCrapo:', '@SenateForeign:', '@SenPatRoberts:', '@JerryMoran:', '@SecWilkie!', '@JerryMoran:', '@SenFinance', '@USTradeRep', '@SenShelby:', '@SenShelby:', '@Airbus', '@SenCoryGardner:', '@SenCoryGardner:', '@SenatorCollins:', '@SenCapito:', '@realDonaldTrump', '@...', '@SenCapito:', '@realDonaldTrump', '@SenCapito:', '@LindseyGrahamSC', '@SenatorFischer:', '@realDonaldTrump', '@SenatorWicker:', '@Varneyco', '@FoxNews', '@Varneyco', '@foxandfriends', '@ByronYork:', '@IngrahamAngle', '@FoxNews.', '@realDonaldTrump:', '@IngrahamAngle', '@FoxNews.', '@realDonaldTrump:', '@WhiteHouse:', '@sendavidperdue:', '@SenTomCotton:', '@FoxNews', '@senatemajldr', '@JudgeJeanine', '@JudgeJeanine', '@GOPLeader:', '@SenTomCotton:', '@SenTomCotton:', '@SenTomCotton:', '@serenawilliams', '@GStephanopoulos,', '@foxandfriends', '@PeteHegseth', '@GreggJarrett', '@foxandfriends', '@realDonaldTrump:', '@DevinNunes', '@MariaBartiromo', '@FoxNews', '@DevinNunes', '@MariaBartiromo', '@FoxNews', '@realDonaldTrump:', '@mohmd_mozafari:', '@FaridMedia:', '@Saiedey:', '@Scarecr0_w:', '@BiggZie_VT:', '@AthenaxWisdom:', '@NarimanGharib:', '@ABC', '@D0wn_Under:', '@realDonaldTrump:', '@realDonaldTrump:', '@realDonaldTrump:', '@GOPLeader:', '@KerriKupecDOJ:', '@BarrettSallee:', '@SenateGOP:', '@JesseMeester:', '@real ...

# %%
print(mentioned_list[0:10])
# Out:
# ['@DevinNunes:', '@heatherjones333:', '@heatherjones333:', '@heatherjones333:', '@heatherjones333:', '@heatherjones333:', '@dcexaminer', '@LindseyGrahamSC:', '@realDonaldTrump', '@dcexaminer:']

# %%
from collections import Counter

# %%
Counter(mentioned_list)
# Out:
# Counter({'@realDonaldTrump': 670,
#          '@realDonaldTrump:': 648,
#          '@WhiteHouse:': 413,
#          '@TeamTrump:': 217,
#          '@FoxNews': 142,
#          '@GOP:': 101,
#          '@GOPChairwoman:': 100,
#          '@GreggJarrett:': 94,
#          '@DanScavino:': 90,
#          '@foxandfriends': 75,
#          '@paulsperry_:': 72,
#          '@BreitbartNews': 68,
#          '@SenateGOP:': 60,
#          '@Jim_Jordan:': 57,
#          '@marklevinshow:': 57,
#          '@LindseyGrahamSC:': 55,
#          '@TrumpWarRoom:': 54,
#          '@DonaldJTrumpJr:': 54,
#          '@dbongino:': 52,
#          '@OANN': 49,
#          '@charliekirk11:': 47,
#          '@CNN': 46,
#          '@USDOT': 46,
#          '@Mike_Pence:': 42,
#          '@senatemajldr:': 41,
#          "@realDonaldTrump's": 40,
#          '@BuckSexton:': 39,
#          '@realDonaldTrump’s': 37,
#          '@TomFitton:': 36,
#          '@FoxNews.': 36,
#          '@LouDobbs:': 35,
#          '@POTUS': 35,
#          '@jsolomonReports:': 35,
#          '@MZHemingway:': 34,
#          '@JohnWHuber:': 34,
#          '@seanhannity': 33,
#          '@Scavino45:': 32,
#          '@GOPLeader:': 32,
#          '@seanhannity:': 32,
#          '@nytimes': 32,
#          '@SaraCarterDC:': 31,
#          '@MarshaBlackburn:': 29,
#          '@EricTrump:': 29,
#          '@AndrewCMcCarthy:': 28,
#          '@IvankaTrump:': 27,
#          '@SenJohnBarrasso:': 27,
#          '@MariaBartiromo': 26,
#          '@DailyCaller:': 26,
#          '@RandPaul:': 26,
#          '@thebradfordfile:': 26,
#          '@realDonaldTrump.': 25,
#          '@JoeBiden': 25,
#          '@TVNewsHQ:': 25,
#          '@SenTomCotton:': 24,
#          '@SenRonJohnson:': 24,
#          '@OANN:': 23,
#          '@CDCgov:': 22,
#          '@PollWatch2020:': 22,
#          '@BrianKempGA': 22,
#          '@RepLeeZeldin:': 21,
#          '@Lrihendry:': 21,
#          '@KimStrassel:': 20,
#          '@realDonaldTrump!': 20,
#          '@seanmdav:': 20,
#          '@DavidJHarrisJr:': 20,
#          '@BreitbartNews.': 20,
#          '@WhiteHouse': 19,
#          '@BreitbartNews:': 19,
#          '@LizRNC:': 19,
#          '@SenTedCruz:': 18,
#          '@HawleyMO:': 18,
#          '@RealJamesWoods:': 17,
#          '@kayleighmcenany:': 17,
#          '@TimMurtaugh:': 17,
#          '@PressSec:': 17,
#          '@NRA:': 17,
#          '@JackPosobiec:': 16,
#          '@realdonaldtrump': 16,
#          '@IngrahamAngle': 16,
#          '@RandPaul': 16,
#          '@FLOTUS': 16,
#          '@greggutfeld': 16,
#          '@marcorubio:': 15,
#          '@RepAndyBiggsAZ:': 15,
#          '@tedcruz:': 15,
#          '@FLOTUS:': 15,
#          '@TuckerCarlson': 15,
#          '@thejtlewis:': 15,
#          '@GenFlynn': 15,
#          '@dcexaminer:': 14,
#          '@ByronYork:': 14,
#          '@SpeakerPelosi': 14,
#          '@LouDobbs': 14,
#          '@JudicialWatch:': 14,
#          '@RichardGrenell:': 14,
#          '@OSeanessyTweet': 14,
#          '@LindseyGrahamSC': 13,
#          '@DineshDSouza:': 13,
#          '@RepMarkMeadows:': 13,
#          '@VP': 13,
#          '@nytimes,': 13,
#          '@MariaBartiromo:': 13,
#          '@NRSC:': 13,
#          '@SenRickScott:': 13,
#          '@thehill:': 13,
#          '@SeanHannity': 13,
#          '@SenJoniErnst:': 13,
#          '@ArthurSchwartz:': 13,
#          '@ScottAdamsSays:': 13,
#          '@TheRightMelissa:': 13,
#          '@TheLeoTerrell:': 13,
#          '@ACTBrigitte:': 13,
#          '@MikeCrapo:': 12,
#          '@JudgeJeanine': 12,
#          '@bennyjohnson:': 12,
#          '@parscale:': 12,
#          '@JohnBoozman:': 12,
#          '@RepMattGaetz:': 12,
#          '@ErinMPerrine:': 12,
#          '@KatrinaPierson:': 12,
#          '@SteveGuest:': 12,
#          '@SenJohnThune:': 12,
#          '@US_FDA': 12,
#          '@nypost': 12,
#          '@VicToensing:': 12,
#          '@HeyTammyBruce:': 12,
#          '@realDonaldTrump,': 11,
#          '@sendavidperdue:': 11,
#          '@JerryMoran:': 11,
#          '@SenCoryGardner:': 11,
#          '@senatemajldr': 11,
#          '@SenatorTimScott:': 11,
#          '@ChuckGrassley:': 11,
#          '@jasoninthehouse:': 11,
#          '@CLewandowski_:': 10,
#          '@GreggJarrett': 10,
#          '@SteveScalise:': 10,
#          '@JimInhofe:': 10,
#          '@brithume:': 10,
#          '@SexCounseling:': 10,
#          '@stillgray:': 10,
#          '@CDCgov': 10,
#          '@BretBaier': 10,
#          '@FoxNews!': 10,
#          '@ScottGottliebMD:': 10,
#          '@IngrahamAngle:': 10,
#          '@mitchellvii:': 10,
#          '@MrAndyNgo:': 10,
#          '@KLoeffler': 10,
#          '@hughhewitt:': 9,
#          '@EliseStefanik:': 9,
#          '@SenatorFischer:': 9,
#          '@Varneyco': 9,
#          '@FoxBusiness': 9,
#          '@SenBillCassidy:': 9,
#          '@FoxNews,': 9,
#          '@RoyBlunt:': 9,
#          '@GeraldoRivera:': 9,
#          '@SenThomTillis:': 9,
#          '@SenMcSallyAZ:': 9,
#          '@RealDonaldTrump': 9,
#          '@ChuckRossDC:': 9,
#          '@SharylAttkisson:': 9,
#          '@washingtonpost,': 9,
#          '@DHSgov': 9,
#          '@NYCMayor': 9,
#          '@RudyGiuliani:': 9,
#          '@BrandonStraka:': 9,
#          '@ACTforAmerica:': 9,
#          '@newsmax': 9,
#          '@OANN,': 9,
#          '@AlwaysActions:': 9,
#          '@LeeSmithDC:': 8,
#          '@JudgeJeanine:': 8,
#          '@SenDanSullivan:': 8,
#          '@SenShelby:': 8,
#          '@SenCapito:': 8,
#          '@marklevinshow': 8,
#          '@KatiePavlich:': 8,
#          '@Varneyco:': 8,
#          '@JonathanTurley:': 8,
#          '@TeamTrump': 8,
#          '@FrancisBrennan:': 8,
#          '@Surabees:': 8,
#          '@WSJ': 8,
#          '@NextRevFNC:': 8,
#          '@SeemaCMS:': 8,
#          '@FEMA': 8,
#          '@USNavy:': 8,
#          '@USTreasury': 8,
#          '@CNN,': 8,
#          '@NYGovCuomo': 8,
#          '@mschlapp:': 8,
#          '@JohnKStahlUSA:': 8,
#          '@JasonMillerinDC:': 8,
#          '@ChanelRion': 8,
#          '@EricEarly_CA:': 8,
#          '@LLinWood:': 8,
#          '@SenatorWicker:': 7,
#          '@PeteHegseth': 7,
#          '@marc_lotter:': 7,
#          '@realDonaldTrump…': 7,
#          '@Jim_Jordan': 7,
#          '@JennaEllisEsq:': 7,
#          '@HouseGOP:': 7,
#          '@RichLowry:': 7,
#          '@RealCandaceO:': 7,
#          '@trish_regan:': 7,
#          '@alx:': 7,
#          '@rea…': 7,
#          '@mattgaetz:': 7,
#          '@KimStrassel': 7,
#          '@MZHemingway': 7,
#          '@Mike_Pence': 7,
#          '@SteveDaines:': 7,
#          '@RudyGiuliani': 7,
#          '@GrassleyPress:': 7,
#          '@SBAgov': 7,
#          '@SenSchumer': 7,
#          '@markknoller:': 7,
#          '@MarkMeadows': 7,
#          '@NRO': 7,
#          '@RichLowry': 7,
#          '@gatewaypundit': 7,
#          '@chucktodd': 7,
#          '@SteveHiltonx': 7,
#          '@dougmillsnyt:': 7,
#          '@PastorDScott:': 7,
#          '@realJeffreyLord:': 7,
#          '@gatewaypundit:': 7,
#          '@Twitter': 7,
#          '@SenJohnKennedy:': 6,
#          '@GrahamLedger:': 6,
#          '@SebGorka:': 6,
#          '@kilmeade': 6,
#          '@RepDougCollins:': 6,
#          '@SenKevinCramer:': 6,
#          '@RepAdamSchiff': 6,
#          '@RepMikeJohnson:': 6,
#          '@Lrihendry': 6,
#          '@AndrewHClark:': 6,
#          '@DHS_Wolf:': 6,
#          '@BorisEP:': 6,
#          '@SecAzar': 6,
#          '@realDonaldTru…': 6,
#          '@SecretarySonny:': 6,
#          '@RealMattCouch:': 6,
#          '@AndrewCMcCarthy': 6,
#          '@60Minutes': 6,
#          '@alexsalvinews:': 6,
#          '@AriFleischer:': 6,
#          '@NASA': 6,
#          '@NASA:': 6,
#          '@SpaceX:': 6,
#          '@SenToomey:': 6,
#          '@theblaze:': 6,
#          '@TrumpStudents:': 6,
#          '@JesseBWatters': 6,
#          '@BrandonStraka': 6,
#          '@AKA_RealDirty:': 6,
#          '@WattersWorld:': 6,
#          '@RaheemKassam:': 6,
#          '@joecollins43rd:': 6,
#          '@SBANYPD:': 6,
#          '@Perduesenate': 6,
#          '@BrianKempGA,': 6,
#          '@DevinNunes:': 5,
#          '@heatherjones333:': 5,
#          '@IvankaTrump': 5,
#          '@SenPatRoberts:': 5,
#          '@DevinNunes': 5,
#          '@KerriKupecDOJ:': 5,
#          '@CBS_Herridge:': 5,
#          '@kayleighmcenany': 5,
#          '@RepDLesko:': 5,
#          '@LaraLeaTrump:': 5,
#          '@SenMikeLee:': 5,
#          '@SenatorBraun:': 5,
#          '@SenatorLankford:': 5,
#          '@LisaMarieBoothe': 5,
#          '@CarlHigbie:': 5,
#          '@BlackVoices4DJT:': 5,
#          '@mirandadevine': 5,
#          '@ericbolling:': 5,
#          '@trish_regan': 5,
#          '@CNN.': 5,
#          '@GovRonDeSantis:': 5,
#          '@SteveDaines': 5,
#          '@SenCoryGardner': 5,
#          '@MarshaBlackburn': 5,
#          '@TommyHicksGOP:': 5,
#          '@GavinNewsom': 5,
#          '@DonaldJTrumpJr': 5,
#          '@RyanAFournier:': 5,
#          '@Techno_Fog:': 5,
#          '@senrobportman:': 5,
#          '@NIH:': 5,
#          '@SenatorRisch:': 5,
#          '@SteveFDA': 5,
#          '@fema': 5,
#          '@FedEx': 5,
#          '@KamVTV:': 5,
#          '@JudiciaryGOP:': 5,
#          '@realDailyWire:': 5,
#          '@washingtonpost': 5,
#          '@OANN.': 5,
#          '@AnthemRespect:': 5,
#          '@ChanelRion:': 5,
#          '@DanCrenshawTX:': 5,
#          '@greg_price11': 5,
#          '@alexdatig:': 5,
#          '@stoolpresidente:': 5,
#          '@RussVought45': 5,
#          '@SpaceX': 5,
#          '@': 5,
#          '@PressSec': 5,
#          '@USDOT.': 5,
#          '@JennPellegrino:': 5,
#          '@KamalaHarris': 5,
#          '@catturd2:': 5,
#          '@MarkMeadows:': 5,
#          '@christina_bobb:': 5,
#          '@ABC13News:': 5,
#          '@GeoffDuncanGA,': 5,
#          '@Lancegooden:': 5,
#          '@SecPompeo:': 4,
#          '@Liz_Wheeler:': 4,
#          '@TomFitton': 4,
#          '@marcthiessen:': 4,
#          '@GOPLeader': 4,
#          '@piersmorgan:': 4,
#          '@ABC': 4,
#          '@madisongesiotto:': 4,
#          '@LaraLeaTrump': 4,
#          '@paulkrugman': 4,
#          '@MorningsMaria': 4,
#          '@realDo…': 4,
#          '@CNBC': 4,
#          '@replouiegohmert:': 4,
#          '@rww_gop:': 4,
#          '@benfergusonshow:': 4,
#          '@JohnCornyn:': 4,
#          '@RedState:': 4,
#          '@dougducey': 4,
#          '@SenJohnHoeven:': 4,
#          '@DLoesch:': 4,
#          '@Rita_Katz:': 4,
#          '@bfraser747': 4,
#          '@oUSA_JEDIo': 4,
#          '@RSBNetwork:': 4,
#          '@nypost:': 4,
#          '@DiamondandSilk:': 4,
#          '@henryrodgersdc:': 4,
#          '@BrandonBeckham_:': 4,
#          '@SenRubioPress:': 4,
#          '@Judgenap': 4,
#          '@SenateGOP': 4,
#          '@marthamaccallum': 4,
#          '@Judgenap:': 4,
#          '@CDCgov,': 4,
#          '@RonnyJackson4TX': 4,
#          '@TwitterMoments:': 4,
#          '@HHSGov,': 4,
#          '@CBPMarkMorgan:': 4,
#          '@SidneyPowell1': 4,
#          '@TIME:': 4,
#          '@TheDemocrats': 4,
#          '@…': 4,
#          '@AP:': 4,
#          '@SecretarySonny': 4,
#          '@BryanDeanWright:': 4,
#          '@BlueAngels': 4,
#          '@nedryun:': 4,
#          '@GenFlynn:': 4,
#          '@RealSLokhova:': 4,
#          '@mikandynothem:': 4,
#          '@Chicago1Ray:': 4,
#          '@NBCNews': 4,
#          '@BernardKerik:': 4,
#          '@newtgingrich:': 4,
#          '@brithume': 4,
#          '@KayleighMcEnany:': 4,
#          '@KarenHandel': 4,
#          '@Space_Station': 4,
#          '@TheJusticeDept': 4,
#          '@glennbeck:': 4,
#          '@NickAdamsinUSA:': 4,
#          '@SecretsBedard:': 4,
#          '@ErrolWebber:': 4,
#          '@TONYxTWO:': 4,
#          '@JoeTalkShow:': 4,
#          '@WashTimes:': 4,
#          '@CortesSteve:': 4,
#          '@KellyannePolls:': 4,
#          '@MrMichaelBurkes:': 4,
#          '@TTuberville,': 4,
#          '@chuckwoolery:': 4,
#          '@RepVernonJones:': 4,
#          '@SeanHannity’s': 4,
#          '@FordOConnell:': 4,
#          '@newsmax:': 4,
#          '@Cernovich:': 4,
#          '@ScottPresler': 4,
#          '@kimKBaltimore:': 4,
#          '@jacobkschneider:': 4,
#          '@cspan': 4,
#          '@ColumbiaBugle:': 4,
#          '@HerschelWalker:': 4,
#          '@gregkellyusa:': 4,
#          '@SenatorWicker': 4,
#          '@newsmax,': 4,
#          '@GamebredFighter': 4,
#          '@scrowder:': 4,
#          '@Perduesenate:': 4,
#          '@sendavidperdue': 4,
#          '@Raiklin:': 4,
#          '@cvpayne': 3,
#          '@abigailmarone:': 3,
#          '@SecPompeo': 3,
#          '@JudicialWatch': 3,
#          '@tedcruz': 3,
#          '@JessieJaneDuff:': 3,
#          '@kilmeade:': 3,
#          '@realDonaldT…': 3,
#          '@SenAlexander:': 3,
#          '@ashleyhayek:': 3,
#          '@RepDougCollins': 3,
#          '@POTUS’': 3,
#          '@bfraser747:': 3,
#          '@RepTedBudd:': 3,
#          '@SenatorCollins': 3,
#          '@SenateDems': 3,
#          '@HeatherChilders': 3,
#          '@RepMarkMeadows': 3,
#          "@realdonaldtrump's": 3,
#          '@AZGOP': 3,
#          '@real…': 3,
#          '@RepDLesko': 3,
#          '@SundayFutures': 3,
#          '@potus': 3,
#          '@DeAnna4Congress:': 3,
#          '@PlaysTrumpCard:': 3,
#          '@PlaysTrumpCard': 3,
#          '@realDonaldTr…': 3,
#          '@NikkiHaley:': 3,
#          '@CarmineSabia:': 3,
#          '@LionelMedia:': 3,
#          '@SenCapito': 3,
#          '@Surgeon_General:': 3,
#          '@MelissaAFrancis:': 3,
#          '@marcorubio': 3,
#          '@SenToddYoung:': 3,
#          '@kevinomccarthy:': 3,
#          '@RichardGrenell,': 3,
#          '@realDonaldTrump.”': 3,
#          '@TeamCavuto': 3,
#          '@johncardillo:': 3,
#          '@narendramodi:': 3,
#          '@realDonaldTrum…': 3,
#          '@jepence:': 3,
#          '@TimMurtaugh': 3,
#          '@comcast': 3,
#          '@CBSNews': 3,
#          '@FischbachMN7': 3,
#          '@Franklin_Graham:': 3,
#          '@GovBillLee': 3,
#          '@MarthaMacCallum': 3,
#          '@realdonaldTrump': 3,
#          '@kimguilfoyle:': 3,
#          '@DrPaulGosar:': 3,
#          '@CNN’s': 3,
#          '@SenateGOP!': 3,
#          '@NIHDirector:': 3,
#          '@CDCtravel:': 3,
#          '@larryelder:': 3,
#          '@LouisianaGov:': 3,
#          '@Surgeon_General': 3,
#          '@HerschelWalker!': 3,
#          '@SBAgov:': 3,
#          '@ChuckGrassley': 3,
#          '@SenHydeSmith:': 3,
#          '@MichaelCoudrey:': 3,
#          '@cvpayne:': 3,
#          '@Breaking911:': 3,
#          '@UPS': 3,
#          '@ChuckCallesto:': 3,
#          '@benshapiro:': 3,
#          '@toddstarnes:': 3,
#          '@CDCDirector:': 3,
#          '@FDA': 3,
#          '@Battelle': 3,
#          '@NYTimes': 3,
#          '@BankofAmerica': 3,
#          '@BrookeSingman:': 3,
#          '@RealSaavedra:': 3,
#          '@fema:': 3,
#          '@GaryCoby:': 3,
#          '@cybergenica:': 3,
#          '@robertjeffress': 3,
#          '@ScottPresler:': 3,
#          '@SenatorTimScott': 3,
#          '@RichardGrenell': 3,
#          '@CardinalDolan': 3,
#          '@CLewandowski_,': 3,
#          '@DarrellIssa:': 3,
#          '@MikeGarcia2020': 3,
#          '@ChristyforCA25': 3,
#          '@JesseBWatters:': 3,
#          '@IAGovernor': 3,
#          '@MikeGarcia2020,': 3,
#          '@ShannonBream:': 3,
#          '@FBI': 3,
#          '@FCC': 3,
#          '@realD…': 3,
#          '@politico': 3,
#          '@DC_Draino:': 3,
#          '@SteveHiltonx:': 3,
#          '@ffweekend': 3,
#          '@MayorBowser': 3,
#          '@WSJ:': 3,
#          '@TTuberville': 3,
#          '@NASA_Astronauts': 3,
#          '@SeanParnellUSA:': 3,
#          '@SidneyPowell1:': 3,
#          '@jack': 3,
#          '@Comey': 3,
#          '@SecretService': 3,
#          '@newtgingrich': 3,
#          '@elonmusk:': 3,
#          '@SarahHuckabee:': 3,
#          '@KDORR_USA:': 3,
#          '@SenRonJohnson': 3,
#          '@SenatorEnzi:': 3,
#          '@WayneDupreeShow:': 3,
#          '@TGowdySC:': 3,
#          '@FoxNews:': 3,
#          '@JayInslee': 3,
#          '@NatalieJHarp:': 3,
#          '@nytimes.': 3,
#          '@ChuckGrassley,': 3,
#          '@RoyCooperNC,': 3,
#          '@heretosaveday07:': 3,
#          '@Hoosiers1986:': 3,
#          '@ggreenwald:': 3,
#          '@AZachParkinson:': 3,
#          '@jennfranconews:': 3,
#          '@GOPChairwoman': 3,
#          '@QuickTake:': 3,
#          '@McKaylaRoseJ': 3,
#          '@LouisianaGov': 3,
#          '@disposable13': 3,
#          '@VFL2013:': 3,
#          '@rkylesmith:': 3,
#          '@mtgreenee:': 3,
#          '@DNI_Ratcliffe': 3,
#          '@RobertCahaly:': 3,
#          '@DNI_Ratcliffe:': 3,
#          '@julie_kelly2:': 3,
#          '@JHoganGidley:': 3,
#          '@washingtonpost:': 3,
#          '@catturd2': 3,
#          '@RSBNetwork!': 3,
#          '@AmyKremer:': 3,
#          '@JamesOKeefeIII:': 3,
#          '@NickForVA:': 3,
#          '@cspan.': 3,
#          '@SenKamalaHarris': 3,
#          '@Project_Veritas:': 3,
#          '@Facebook': 3,
#          '@BeanfromPa:': 3,
#          '@cjtruth:': 3,
#          '@chefjclark:': 3,
#          '@KLoeffler:': 3,
#          '@kylenabecker:': 3,
#          '@alexbruesewitz:': 3,
#          '@SenMastriano:': 3,
#          '@iheartmindy:': 3,
#          '@JimInhofe': 3,
#          '@KanekoaTheGreat:': 3,
#          '@wesrap:': 3,
#          '@MichSoS': 3,
#          '@foxandfriends.': 2,
#          '@TuckerCarlson:': 2,
#          '@SecPompeo,': 2,
#          '@EsperDoD,': 2,
#          '@MatthewJshow:': 2,
#          '@SenateForeign:': 2,
#          '@greggutfeld:': 2,
#          '@POTUS’s': 2,
#          '@LaraLeaTrump,': 2,
#          '@MSNBC': 2,
#          '@realDonal…': 2,
#          '@OliverMcGee:': 2,
#          '@WHNSC': 2,
#          '@UFC': 2,
#          '@FIFAWorldCup': 2,
#          '@cindyhydesmith:': 2,
#          '@ScottforFlorida:': 2,
#          '@JoeSquawk': 2,
#          '@TedCruz:': 2,
#          '@TPPatriots:': 2,
#          '@LevinTV:': 2,
#          '@RepRonWright:': 2,
#          '@NBCNews,': 2,
#          '@JackPosobiec': 2,
#          '@cspan:': 2,
#          '@realDonaldTrump.…': 2,
#          '@r…': 2,
#          '@dougducey:': 2,
#          '@DrPaulGosar': 2,
#          '@TGowdySC': 2,
#          '@RepRatcliffe': 2,
#          '@RepLeeZeldin': 2,
#          '@joegooding:': 2,
#          '@TheFirstonTV:': 2,
#          '@EliseStefanik': 2,
#          '@CBSNews:': 2,
#          '@Babin4Congress': 2,
#          '@MichaelCBurgess': 2,
#          '@AnthemRespect': 2,
#          '@ROHLL5': 2,
#          '@atensnut': 2,
#          '@CarmineSabia': 2,
#          '@SenatorRisch': 2,
#          '@SecAzar:': 2,
#          '@CoryBooker': 2,
#          '@SenatorDole:': 2,
#          '@RepMattGaetz': 2,
#          '@AmericaFirstPAC:': 2,
#          '@SenThomTillis': 2,
#          '@bigleaguepol:': 2,
#          '@DougJones': 2,
#          '@josepheschmitz:': 2,
#          '@WMUR9:': 2,
#          '@McHenryCampaign': 2,
#          '@NASCAR': 2,
#          '@JenniferJJacobs:': 2,
#          '@NASCAR:': 2,
#          '@USMC:': 2,
#          '@GOP': 2,
#          '@HARRISFAULKNER': 2,
#          '@foxnews': 2,
#          '@JuddPDeere45:': 2,
#          '@LucasFoxNews:': 2,
#          '@Jamierodr14:': 2,
#          '@narendramodi': 2,
#          '@yalinunez:': 2,
#          '@gr8tjude_08:': 2,
#          '@TocRadio:': 2,
#          '@SaraCarterDC': 2,
#          '@SteveDaines.': 2,
#          '@LanceGooden': 2,
#          '@HHSgov': 2,
#          '@AndrewDesiderio:': 2,
#          '@SenTomCotton': 2,
#          '@edhenry': 2,
#          '@FoxNews.…': 2,
#          '@PARISDENNARD:': 2,
#          '@CompoundBoss:': 2,
#          '@HHSGov': 2,
#          '@MariaLeeTN.': 2,
#          '@amyklobuchar': 2,
#          '@SenatorTimScott!': 2,
#          '@StevenPalazzo': 2,
#          '@ChadPergram:': 2,
#          '@HHSGov:': 2,
#          '@BW:': 2,
#          '@USATODAY:': 2,
#          '@Jentezen': 2,
#          '@Google_Comms:': 2,
#          '@AFP:': 2,
#          '@AjitPaiFCC:': 2,
#          '@SteveFDA:': 2,
#          '@WHOSTP': 2,
#          '@SenJoniErnst': 2,
#          '@SecretService:': 2,
#          '@JennPellegrino': 2,
#          '@SenHawleyPress:': 2,
#          '@RepMichaelWaltz:': 2,
#          '@KenCalvert:': 2,
#          '@TeamCavuto:': 2,
#          '@ltgrusselhonore': 2,
#          '@stevenmnuchin1': 2,
#          '@FedupMil:': 2,
#          '@steph93065:': 2,
#          '@SpeakerPelosi?': 2,
#          '@NanHayworth:': 2,
#          '@USACEHQ,': 2,
#          '@FEMA,': 2,
#          '@DeptofDefense:': 2,
#          '@GEHealthcare': 2,
#          '@USNationalGuard,': 2,
#          '@SBAJovita:': 2,
#          '@FitnessGov': 2,
#          '@AdrianaCohen16:': 2,
#          '@LisaMarieBoothe:': 2,
#          '@DanaPerino:': 2,
#          '@AGHamilton29:': 2,
#          '@MediaBuzzFNC:': 2,
#          '@AmberSmithUSA:': 2,
#          '@nytimes)': 2,
#          '@USACE_NY:': 2,
#          '@POTUS,': 2,
#          '@SecondLady': 2,
#          '@CNBCnow:': 2,
#          '@BBCBreaking:': 2,
#          '@realDailyWire': 2,
#          '@robertjeffress:': 2,
#          '@T…': 2,
#          '@HillaryClinton': 2,
#          '@Yankees': 2,
#          '@GM': 2,
#          '@Honeywell,': 2,
#          '@realKTMcFarland,': 2,
#          '@RepDanCrenshaw': 2,
#          '@LindaSuhler:': 2,
#          '@SecondLady:': 2,
#          '@BarbaraRedgate:': 2,
#          '@GregAbbott_TX': 2,
#          '@AFThunderbirds!': 2,
#          '@GLFOP:': 2,
#          '@EquipoTrump:': 2,
#          '@mercedesschlapp': 2,
#          '@kevinomccarthy': 2,
#          '@JimRyun!': 2,
#          '@RepLizCheney:': 2,
#          '@StevenTDennis:': 2,
#          '@TheHillOpinion': 2,
#          '@thejtlewis': 2,
#          '@Alyssafarah:': 2,
#          '@Reuters:': 2,
#          '@RepGosar:': 2,
#          '@DavidMuir': 2,
#          '@ABCWorldNews': 2,
#          '@Honeywell!': 2,
#          '@MikeGarcia2020:': 2,
#          '@EliLake:': 2,
#          '@AdamSchiff': 2,
#          '@MarkSimoneNY:': 2,
#          '@60Minutes,': 2,
#          '@BarackObama': 2,
#          '@smalltownandrew:': 2,
#          '@F…': 2,
#          '@AjitPaiFCC': 2,
#          '@JohnParshon': 2,
#          '@CBS_Herridge': 2,
#          '@elonmusk': 2,
#          '@PulitzerPrizes': 2,
#          '@BritHume': 2,
#          '@SpaceForceDoD': 2,
#          '@CPAC:': 2,
#          '@Heritage:': 2,
#          '@JOEBIDEN?': 2,
#          '@trimet': 2,
#          '@USDA': 2,
#          '@AlanDersh:': 2,
#          '@WSJopinion:': 2,
#          '@KatrinaPierson': 2,
#          '@AMErikaNGIRLLL:': 2,
#          '@ksorbs:': 2,
#          '@LouDobbs!': 2,
#          '@realDon…': 2,
#          '@MarieLeff:': 2,
#          '@PGHtransit': 2,
#          '@YoungDems4Trump:': 2,
#          '@SecretService.': 2,
#          '@NASAKennedy': 2,
#          '@Astro_Doug': 2,
#          '@AstroBehnken': 2,
#          '@greta:': 2,
#          '@DineshDSouza': 2,
#          '@senjudiciary': 2,
#          '@esaagar:': 2,
#          '@dagenmcdowell:': 2,
#          '@nytimes:': 2,
#          '@senjudiciary:': 2,
#          '@jasoninthehouse': 2,
#          '@realDona…': 2,
#          '@SenateVA': 2,
#          '@DeptVetAffairs': 2,
#          '@Rasmussen_Poll:': 2,
#          '@TedCruz': 2,
#          '@SeanParnellUSA,': 2,
#          '@SenJohnKennedy': 2,
#          '@SenBillCassidy': 2,
#          '@NancyMace!': 2,
#          '@NancyMace': 2,
#          '@PerdueSenate...': 2,
#          '@JoniErnst!': 2,
#          '@DeAngelisCorey:': 2,
#          '@bdomenech:': 2,
#          '@TomBevanRCP:': 2,
#          '@JaRonSmith45:': 2,
#          '@MattGaetz': 2,
#          '@HerschelWalker': 2,
#          '@JamesComer': 2,
#          '@MarkwayneMullin': 2,
#          '@AllenWest:': 2,
#          '@CorkyForSenate:': 2,
#          '@NHTrumpVictory': 2,
#          '@CoryGardner': 2,
#          '@KayleighMcEnany': 2,
#          '@ODNIgov:': 2,
#          '@TheLeoTerrell': 2,
#          '@MikeCrapo': 2,
#          '@BrentBozell:': 2,
#          '@yogagenie:': 2,
#          '@DanScavino': 2,
#          '@SierraWhiskee:': 2,
#          '@DonaldJTrumpJr,': 2,
#          '@WashTimes': 2,
#          '@lopezobrador_': 2,
#          '@Southcom': 2,
#          '@Southcom:': 2,
#          '@GoyaFoods!': 2,
#          '@gregsteube:': 2,
#          '@NRAPVF': 2,
#          '@JoeBiden.': 2,
#          '@TomCottonAR:': 2,
#          '@jonvoight:': 2,
#          '@SydneyLWatson:': 2,
#          '@MarkDice:': 2,
#          '@maggieNYT': 2,
#          '@SASCMajority,': 2,
#          '@JonathanTurley': 2,
#          '@wesbury:': 2,
#          '@ShellenbergerMD:': 2,
#          '@jessebwatters': 2,
#          '@ChristianWalk1r:': 2,
#          '@theangiestanton:': 2,
#          '@EdwardLawrence:': 2,
#          '@KurtSchlichter:': 2,
#          '@PeteStauber': 2,
#          '@buds1008:': 2,
#          '@MichelleMakori:': 2,
#          '@RRocksss:': 2,
#          '@RJC:': 2,
#          '@SPWTalessia:': 2,
#          '@NYCPBA!': 2,
#          '@michaelahrens:': 2,
#          '@Pismo_B:': 2,
#          '@LATAMforTRUMP:': 2,
#          '@Peoples_Pundit:': 2,
#          '@DGPurser:': 2,
#          '@JaredKushner:': 2,
#          '@mattdizwhitlock:': 2,
#          '@Heminator:': 2,
#          '@skb_sara:': 2,
#          '@DeanBrowningPA:': 2,
#          '@DrewHolden360:': 2,
#          '@TheBabylonBee:': 2,
#          '@LarrySchweikart:': 2,
#          '@trafalgar_group': 2,
#          '@TimRunsHisMouth:': 2,
#          '@TheNatPulse:': 2,
#          '@predsednikrs': 2,
#          '@starsandstripes': 2,
#          '@RussVought45:': 2,
#          '@EmeraldRobinson:': 2,
#          '@DrKarlynB:': 2,
#          '@JeffreyGoldberg': 2,
#          '@Mowers!': 2,
#          '@AdamLaxalt:': 2,
#          '@ClayTravis:': 2,
#          '@SarahHuckabee': 2,
#          '@laurenboebert:': 2,
#          '@LizMacDonaldFOX': 2,
#          '@Joy_Villa:': 2,
#          '@therecount:': 2,
#          '@ScottAdamsSays': 2,
#          '@johnrobertsFox:': 2,
#          '@IvanPentchoukov:': 2,
#          '@Avik:': 2,
#          '@YouTube': 2,
#          '@Thomas1774Paine:': 2,
#          '@KDKA:': 2,
#          '@joshdcaplan:': 2,
#          '@MikeKellyforPA:': 2,
#          '@RaheemKassam': 2,
#          '@kaitlancollins': 2,
#          '@NRA_Rifleman:': 2,
#          '@GrrrGraphics:': 2,
#          '@mikehahn_:': 2,
#          '@politico:': 2,
#          '@GroverNorquist:': 2,
#          '@Lisa_Matassa:': 2,
#          '@beyondreasdoubt:': 2,
#          '@hrenee80:': 2,
#          '@EveningEdit': 2,
#          '@RealJamesWoods': 2,
#          '@ApplePodcasts': 2,
#          '@iTunes': 2,
#          '@1776Stonewall:': 2,
#          '@coloradodems': 2,
#          '@Hansen4Congress:': 2,
#          '@TexasGOP:': 2,
#          '@SenSasse': 2,
#          '@PamBondi:': 2,
#          '@CindyHydeSmith': 2,
#          '@JoeBiden!': 2,
#          '@Google.': 2,
#          '@realannapaulina:': 2,
#          '@JoeConchaTV:': 2,
#          '@mschlapp': 2,
#          '@AdamLaxalt': 2,
#          '@BuckForColorado:': 2,
#          '@AndrewPollackFL:': 2,
#          '@PastorDScott’s': 2,
#          '@RealAmVoice.': 2,
#          '@RandyRRQuaid:': 2,
#          '@yossi_melman:': 2,
#          '@BrianKempGA.': 2,
#          '@MarkFinchem:': 2,
#          '@Rothbard1776:': 2,
#          '@GeoffDuncanGA': 2,
#          '@unscriptedmike:': 2,
#          '@staceyabrams': 2,
#          '@KelemenCari:': 2,
#          '@jessiprincey:': 2,
#          '@KMCRadio:': 2,
#          '@dcexaminer': 1,
#          "@SenJoniErnst's": 1,
#          '@ThisWeekABC:': 1,
#          '@ATT': 1,
#          '@realDonaldTrump.This': 1,
#          '@VP:': 1,
#          '@JesseKellyDC:': 1,
#          '@USEmbBaghdad:': 1,
#          '@TravelGov:': 1,
#          '@jimsciutto:': 1,
#          '@samdagher:': 1,
#          '@W...': 1,
#          '@mrglenn:': 1,
#          '@BradThor:': 1,
#          '@SpeakerPelosi’s': 1,
#          "@tedcruz's": 1,
#          '@kbsalsaud': 1,
#          '@JennyGuice:': 1,
#          '@mike_pence:': 1,
#          '@realDonaldTru...': 1,
#          '@StewardshipAmer:': 1,
#          '@GovernorLittle:': 1,
#          '@SecWilkie!': 1,
#          '@SenFinance': 1,
#          '@USTradeRep': 1,
#          '@Airbus': 1,
#          '@SenatorCollins:': 1,
#          '@...': 1,
#          '@serenawilliams': 1,
#          '@GStephanopoulos,': 1,
#          '@mohmd_mozafari:': 1,
#          '@FaridMedia:': 1,
#          '@Saiedey:': 1,
#          '@Scarecr0_w:': 1,
#          '@BiggZie_VT:': 1,
#          '@AthenaxWisdom:': 1,
#          '@NarimanGharib:': 1,
#          '@D0wn_Under:': 1,
#          '@BarrettSallee:': 1,
#          '@JesseMeester:': 1,
#          '@HeatherChilders:': 1,
#          '@AmericaNewsroom': 1,
#          '@BillHemmer:': 1,
#          '@BorisJohnson,': 1,
#          '@heytana:': 1,
#          '@StumpforTrump:': 1,
#          '@MAGAindex:': 1,
#          '@michaeljknowles:': 1,
#          '@SenWarren,': 1,
#          '@SenAmyKlobuchar,': 1,
#          '@SenatorBennet': 1,
#          '@adamgoldmanNYT:': 1,
#          '@NBCPolitics:': 1,
#          '@mercedesschlapp,': 1,
#          '@AlanDersh': 1,
#          '@ScottFordTVGuy:': 1,
#          '@LSUfootball:': 1,
#          '@La…': 1,
#          '@StephenMoore': 1,
#          '@mercedesschlapp:': 1,
#          '@ashleyhayek': 1,
#          '@CHC_1927:': 1,
#          "@BillClinton's": 1,
#          '@FoxNews…': 1,
#          '@RichardGrenell!': 1,
#          '@wef:': 1,
#          '@GiannoCaldwell:': 1,
#          '@FoxBusin…': 1,
#          '@EricaforUSSen20': 1,
#          "@chuckschumer's": 1,
#          '@Calfo…': 1,
#          '@Hickenlooper.': 1,
#          '@DSCC)': 1,
#          '@Hickenlooper': 1,
#          '@Hickenlooper...': 1,
#          '@MarthaMcSally:': 1,
#          '@MarthaMcSally,': 1,
#          '@Davos.': 1,
#          '@SenSchumer...': 1,
#          '@dbongino!': 1,
#          ...})

# %%
# mentions= [word.rstrip(punctuation) for word in TrumpTweets if word.startswith('@')]

# %%
from string import punctuation

# %%
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
"@readlDonaldTrump".rstrip(punctuation)
# Out:
# '@readlDonaldTrump'
